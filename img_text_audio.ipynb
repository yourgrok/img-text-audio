# %% [markdown]
# <a href="https://colab.research.google.com/github/yourgrok/img-text-audio/blob/main/img_text_audio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt install tesseract-ocr
# !pip install pytesseract
# !pip install gTTS
# !pip install Pillow==9.0.0
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 35 not upgraded.
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 3.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: click
#     Found existing installation: click 8.2.1
#     Uninstalling click-8.2.1:
#       Successfully uninstalled click-8.2.1
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 MB 14.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for Pillow: filename=Pillow-9.0.0-cp311-cp311-linux_x86_64.whl size=1177674 sha256=1a4c5d9c5fc62706cf58bfb76c6e5b6fafd5b2d96c7dfd2859a5181f750e64bb
#   Stored in directory: /root/.cache/pip/wheels/0c/83/93/7ecd5a526f27268c0d6d47c5906dc7d368748226e281caf158
# Successfully built Pillow
# ...
#   Attempting uninstall: Pillow
#     Found existing installation: pillow 11.3.0
# ...

# %%
import pytesseract
from PIL import Image
import gtts

# %%
img = Image.open('/content/textpic.png')
print(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=310x163 at 0x7F87E8B89C50>

# %%
result = pytesseract.image_to_string(img)
print(result)
tts = gtts.gTTS(result)
tts.save("hello.mp3")
# Out:
# Selecting
# TYPEFACES
#
# for body text

# %%
from IPython.display import Audio

# Play the existing hello.mp3 file in the Colab environment
Audio("/content/hello.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# H.W : Write code to play this audio file in colab
